# %% [markdown]
# sol 1
#
# As a given average rate in a particular duration is given poisson distribution is the appropriate choice

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# sol 2
#
# Yes the distribution of X and Yare same
#
# ![image.png](attachment:image.png)
